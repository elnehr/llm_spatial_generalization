# %% [markdown]
# # 1. Imports

# %%
from langchain.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)
from langchain_core.messages import HumanMessage, SystemMessage
from openai import AsyncOpenAI
from anthropic import AsyncAnthropic
from langchain.llms import HuggingFaceHub
import os

import pandas as pd
import os
import json
import matplotlib.pyplot as plt
import numpy as np
import csv
#import seaborn as sns

import asyncio
from aiolimiter import AsyncLimiter
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)

from models import *

os.environ["HUGGINGFACEHUB_API_TOKEN"] = ""
os.environ["ANTHROPIC_API_KEY"] = ""
os.environ["OPENAI_API_KEY"] = ""

# %% [markdown]
# # 2. Data Imports

# %% [markdown]
# ## 2.1 US FFA Exam

# %%
ffa_soil_practicum = pd.read_csv(r'../regional_best_practices/soil_exams/ffa_soil_practicum.csv')
ffa_soil_practicum
# Out:
#                                              question answer region
# 0   Soil has two key characteristics that help to ...      B    USA
# 1   World‐wide, soils have been classified into so...      C    USA
# 2   What soil taxonomy order is found in the dries...      A    USA
# 3   One soil order is comprised of deeply weathere...      A    USA
# 4   Which soil would be the most likely to resist ...      B    USA
# 5   Using a soil texture triangle, what type of so...      C    USA
# 6   Using the soil texture triangle, select the co...      C    USA
# 7   The soil consists of four major components i.e...      D    USA
# 8   Soil texture is made up of soil particles and ...      D    USA
# 9   Field capacity is the point where the soil wat...      B    USA
# 10  World‐wide, soils have been classified into so...      B    USA
# 11  What soil type comprises the greatest area of ...      C    USA
# 12  One soil type has a high amount of clay and sh...      A    USA
# 13  Soil formation factors consist of 5 identified...      B    USA
# 14  The letter R is used in some soil profile desc...      B    USA
# 15  Using a soil texture triangle, what type of so...      D    USA
# 16  Soil “A” has 45% clay, 45% silt, and 10% sand....      D    USA
# 17  As an agronomist a farmer has ask you to evalu...      C    USA
# 18  A soil profile is made up of horizons. In the ...      C    USA
# 19  Soil structure is defined by the way individua...      A    USA
# 20  World‐wide, soils have been classified into so...      D    USA
# 21  What soil order is found in the coldest region...      B    USA
# 22  One soil order is comprised mainly of organic ...      A    USA
# 23  Which soil would be the most likely to resist ...      B    USA
# 24  Using a soil texture triangle, what type of so...      D    USA
# 25  Using the Soil Texture Triangle, select the co...      A    USA
# 26  The soil consists of four major components i.e...      C    USA

# %% [markdown]
# ## 2.2 Brazil Expert Q&A

# %%
json_pattern = os.path.join(
    "..", "regional_best_practices", "brazil_questions", "bulk", "*.json"
)

file_list = [f for f in glob.glob(json_pattern, recursive=True)]


brazil_questions = pd.read_json(r'D:\Users\elias\Desktop\Oxford lab rotation\llm_spartial_generalization\regional_best_practices\brazil_questions\bulk\bulk-algodao.json', lines=True)
brazil_questions = brazil_questions[["question", "answer"]].dropna().sample(n=20)

for file in file_list[1:]:
    #open file as dataframe
    df = pd.read_json(file, lines=True).drop(columns= ["index"]).dropna()
    # randomly select 25 questions	
    df = df.sample(n=20)
    #append to brazil_questions
    brazil_questions = pd.concat([brazil_questions, df[["question", "answer"]].dropna()], ignore_index=True)

brazil_questions["region"] = "Brazil"

# save questions to csv
brazil_questions.to_csv(r'../regional_best_practices/brazil_questions/brazil_questions.csv', index = False)

# %%
brazil_questions = pd.read_csv(r'../regional_best_practices/brazil_questions/brazil_questions.csv')
brazil_questions
# Out:
#                                               question  \
# 0    Quais os delineamentos experimentais mais usad...
# 1                          O que é um fio texturizado?
# 2    Existe controle químico para doenças causadas ...
# 3    Como é feita a alimentação da usina para o ben...
# 4    Quais as cultivares resistentes a doenças, dis...
# ..                                                 ...
# 215  Qual é o efeito do ambiente sobre a aplicação ...
# 216  A adubação de manutenção do vinhedo deve ser r...
# 217              O que é a análise sensorial do vinho?
# 218  A que distância do solo deve ficar a região da...
# 219       Como acondicionar os cachos nos contentores?
#
#                                                 answer  region
# 0    <p>Os delineamentos experimentais utilizados n...  Brazil
# 1    <p>É o fio constituído por filamentos, aos qua...  Brazil
# 2    <p>Sim. Porém, seu uso não é comum em virtude ...  Brazil
# 3    <p>Os fardões de algodão em caroço são desmanc...  Brazil
# 4    <p>As cultivares resistentes a doenças, dispon...  Brazil
# ..                                                 ...     ...
# 215  <p>O vento, a temperatura e a umidade relativa...  Brazil
# 216  <p>Se o vinhedo for conduzido conforme os crit...  Brazil
# 217  <p>É a avaliação qualitativa do vinho, efetuad...  Brazil
# 218  <p>No caso de muda enxertada, é conveniente qu...  Brazil
# 219  <img alt="Acondicionamento dos cachos nos cont...  Brazil
#
# [220 rows x 3 columns]

# %% [markdown]
# ## 2.3 India Exam

# %%
# load temp_data\india_quiz_questions.json

india_questions = pd.read_json(r'../temp_data/india_quiz_questions.json')

india_questions["region"] = "India"
india_questions["question"] = india_questions["question"] + " Answer options: " + india_questions["answer_options"]
india_questions.drop(columns=["answer_options"], inplace=True)
india_questions = india_questions.rename(columns={"correct_answer": "answer"})

india_questions
# Out:
#                                               question answer region
# 0    Glycolysis is known as? Answer options: A. EMP...      A  India
# 1    “Cell Organiser” is? Answer options: A. Riboso...      B  India
# 2    Rice seed is known as? Answer options: A. Pod,...      D  India
# 3    Paddy inflorescence is? Answer options: A. Ear...      D  India
# 4    Fruit ripening hormone? Answer options: A. Cyt...      C  India
# ..                                                 ...    ...    ...
# 282  Muga silk is reared on? Answer options: A) Som...      A  India
# 283  When the plant is propagated by small tissue o...      B  India
# 284  Which among the following is the highest prior...      A  India
# 285  Which of the following is a bacterial infectio...      D  India
# 286  Method of drainage that is used in high water ...      B  India
#
# [287 rows x 3 columns]

# %%
questions_df = pd.DataFrame(columns=["question", "answer", "region"])
questions_df = pd.concat([questions_df, india_questions, brazil_questions, ffa_soil_practicum])
questions_df
# Out:
#                                              question answer region
# 0   Glycolysis is known as? Answer options: A. EMP...      A  India
# 1   “Cell Organiser” is? Answer options: A. Riboso...      B  India
# 2   Rice seed is known as? Answer options: A. Pod,...      D  India
# 3   Paddy inflorescence is? Answer options: A. Ear...      D  India
# 4   Fruit ripening hormone? Answer options: A. Cyt...      C  India
# ..                                                ...    ...    ...
# 22  One soil order is comprised mainly of organic ...      A    USA
# 23  Which soil would be the most likely to resist ...      B    USA
# 24  Using a soil texture triangle, what type of so...      D    USA
# 25  Using the Soil Texture Triangle, select the co...      A    USA
# 26  The soil consists of four major components i.e...      C    USA
#
# [534 rows x 3 columns]

# %% [markdown]
# # 3. Answer Generation

# %% [markdown]
# ## 3.1 HuggingFace Models

# %%
models = {
    "gemma_7b_it": gemma_7b_it,
    "gemma_2b_it": gemma_2b_it,
    "mistral_7b": mistral_7b,
    "mistral_8x7b": mistral_8x7b,
    "llama2_7b": llama2_7b,
    "llama2_13b": llama2_13b,
}

# %%
prompts = ["""Answer the given question. Return the LETTER of the correct answer.""",
    """You are an expert in agriculture. Answer the given question about agriculture. Return the LETTER of the correct answer.""",
    """You are an expert in agriculture. Answer the given question about agriculture truthfully, concisely, and precisely for the described location. Return the LETTER of the correct answer.""",
    """You are an expert in agriculture. Answer the given question about agriculture truthfully, concisely, and precisely for the described location. If you answer correctly, you will receive $1,000. If you answer incorrectly, you will be fined $1,000. Return the LETTER of the correct answer.""",
    """You are an expert in agriculture. Answer the given question about agriculture truthfully, concisely, and precisely for the described location. 
    Think step by step. FIRST, start with a "Thought:" step, where you think about possible answer options. Be critical of your answer and think of the possible options to answer the given question. THEN, based on these considerations, give in the "Final Answer:" step your final answer. Return the LETTER of the correct answer."""
]

# %%
quiz_results_hf_df = pd.DataFrame(columns=["question", "template_answer", "llm_answer", "region", "model", "prompt"])

i = 0

for index, dict in questions_df.iterrows():
    i += 1
    print("################## " + str(i))
    question = dict['question']
    region = dict['region']
    template_answer = dict['answer']
    question = "Region: " + region + ", Question: " + question
    for prompt in prompts:
        for model in models:
            print(model)
            completion = models[model](prompt, question)
            # evaluation = chat(evaluation_chat_prompt.format_prompt(question=question, template_answer=template_answer, student_answer=completion).to_messages()).content
            new_row = pd.DataFrame([{"question": question, "template_answer": template_answer, "llm_answer": completion, "model": model, "region": region, "prompt": prompt}])
            quiz_results_df = pd.concat([quiz_results_df, new_row], ignore_index=True)
        print(completion)
    quiz_results_hf_df.to_csv(r'../temp_data/quiz_results_hf_df.csv', sep = ';', index = False)

# %%
quiz_results_hf_df

# %% [markdown]
# ## 3.2. OpenAI Models

# %%
client = AsyncOpenAI(api_key="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")

@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(20))
async def async_gpt_3_5_turbo(prompt, user_input):
    response = await client.chat.completions.create(
    model="gpt-3.5-turbo-0125",
    messages=[
        {"role": "system", "content": prompt},
        {"role": "user", "content": user_input}
    ]
    )
    return response.choices[0].message.content



@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(20))
async def async_gpt_4_turbo(prompt, user_input):
    response = await client.chat.completions.create(
    model="gpt-4-turbo-preview",
    messages=[
        {"role": "system", "content": prompt},
        {"role": "user", "content": user_input}
    ]
    )
    return response.choices[0].message.content

# %%
oa_models = {
    "gpt_4_turbo": async_gpt_4_turbo,
    "gpt_3_5_turbo": async_gpt_3_5_turbo
}

# %%
# Initialize AsyncLimiter: 100 operations per minute means approximately 1.67 operations per second.
limiter = AsyncLimiter(5, 1)

# Assuming json_evaluation_multiple_seasons is an async function that accepts a text and returns a JSON.

quiz_results_oa_df = pd.DataFrame()

async def async_eval(prompt, model, row):
    question = row['question']
    region = row['region']
    template_answer = row['answer']
    question = "Region: " + region + ", Question: " + question
    completion = await oa_models[model](prompt, question)
    new_row = {"question": question, "template_answer": template_answer, "llm_answer": completion, "model": model, "region": region, "prompt": prompt}
    return new_row

async def process_documents(documents_df):
    tasks = []
    for index, row in documents_df.iterrows():
        for prompt in prompts:
            for model in oa_models:
                async with limiter:
                    task = asyncio.create_task(async_eval(prompt, model, row))
                    tasks.append(task)
    results = await asyncio.gather(*tasks, return_exceptions=True)
    print(results)
    for result in results:
        if isinstance(result, Exception):
            print(f"An error occurred: {result}")
    return pd.DataFrame([result for result in results if not isinstance(result, Exception)])


# In case the loop is already running, avoid using loop.run_until_complete()
if not loop.is_running():
    quiz_results_oa_df = loop.run_until_complete(process_documents(questions_df))
else:
    quiz_results_oa_df = await process_documents(questions_df) 


quiz_results_oa_df.to_csv(r'../temp_data/quiz_results_oa_df.csv', sep = ';', index = False)

quiz_results_oa_df

# %%
quiz_results_oa_df

# %% [markdown]
# ## 3.3. Anthopic Models

# %%
client = AsyncAnthropic()


@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(20))
async def async_claude_instant(prompt, user_input):
    response = await client.messages.create(
        max_tokens=2048,
        messages=[
            {
                "role": "user",
                "content": prompt + """ 
                
                """ + user_input,
            }
        ],
        model="claude-instant-1.2",
    )
    return response.choices[0].message.content


@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(20))
async def async_claude_3_sonnet(prompt, user_input):
    response = await client.messages.create(
        max_tokens=2048,
        system= prompt,
        messages=[
            {
                "role": "user",
                "content": user_input
            }
        ],
        model="claude-3-sonnet-20240229",
    )
    return response


@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(20))
async def async_claude_3_opus(prompt, user_input):
    response = await client.messages.create(
        max_tokens=2048,
        system= prompt,
        messages=[
            {
                "role": "user",
                "content": user_input
            }
        ],
        model="claude-3-opus-20240229",
    )
    return response.choices[0].message.content

# %%
anthropic_models = {
    "claude_instant": async_claude_instant,
    "claude_3_sonnet": async_claude_3_sonnet,
    "claude_3_opus": async_claude_3_opus
}

# %%
# Initialize AsyncLimiter: 100 operations per minute means approximately 1.67 operations per second.
limiter = AsyncLimiter(1, 1)

# Assuming json_evaluation_multiple_seasons is an async function that accepts a text and returns a JSON.

quiz_results_anthropic_df = pd.DataFrame()

async def async_eval(prompt, model, row):
    question = row['question']
    region = row['region']
    template_answer = row['answer']
    question = "Region: " + region + ", Question: " + question
    completion = await anthropic_models[model](prompt, question)
    new_row = {"question": question, "template_answer": template_answer, "llm_answer": completion, "model": model, "region": region, "prompt": prompt}
    return new_row

async def process_documents(documents_df):
    tasks = []
    for index, row in documents_df.iterrows():
        for prompt in prompts:
            for model in anthropic_models:
                async with limiter:
                    task = asyncio.create_task(async_eval(prompt, model, row))
                    tasks.append(task)
                    if len(tasks) % 5 == 0:
                        print(f"Submitted {len(tasks)} tasks")
    results = await asyncio.gather(*tasks, return_exceptions=True)
    print(results)
    for result in results:
        if isinstance(result, Exception):
            print(f"An error occurred: {result}")
    return pd.DataFrame([result for result in results if not isinstance(result, Exception)])


# In case the loop is already running, avoid using loop.run_until_complete()
if not loop.is_running():
    quiz_results_anthropic_df = loop.run_until_complete(process_documents(questions_df[150:250]))
else:
    quiz_results_anthropic_df = await process_documents(questions_df[150:250]) 


quiz_results_anthropic_df.to_csv(r'../temp_data/quiz_results_anthropic_df2.csv', sep = ';', index = False)

quiz_results_anthropic_df
# Out:
# Submitted 5 tasks
# Submitted 10 tasks
# Submitted 15 tasks
# Submitted 20 tasks
# Submitted 25 tasks
# Submitted 30 tasks
# Submitted 35 tasks
# Submitted 40 tasks
# Submitted 45 tasks
# Submitted 50 tasks
# Submitted 55 tasks
# Submitted 60 tasks
# Submitted 65 tasks
# Submitted 70 tasks
# Submitted 75 tasks
# Submitted 80 tasks
# Submitted 85 tasks
# Submitted 90 tasks
# Submitted 95 tasks
# Submitted 100 tasks
# Submitted 105 tasks
# Submitted 110 tasks
# Submitted 115 tasks
# Submitted 120 tasks
# Submitted 125 tasks
# Submitted 130 tasks
# Submitted 135 tasks
# Submitted 140 tasks
# Submitted 145 tasks
# Submitted 150 tasks
# Submitted 155 tasks
# Submitted 160 tasks
# Submitted 165 tasks
# Submitted 170 tasks
# Submitted 175 tasks
# Submitted 180 tasks
# Submitted 185 tasks
# Submitted 190 tasks
# Submitted 195 tasks
# Submitted 200 tasks
# Submitted 205 tasks
# Submitted 210 tasks
# Submitted 215 tasks
# Submitted 220 tasks
# Submitted 225 tasks
# Submitted 230 tasks
# Submitted 235 tasks
# Submitted 240 tasks
# Submitted 245 tasks
# Submitted 250 tasks
# Submitted 255 tasks
# Submitted 260 tasks
# Submitted 265 tasks
# Submitted 270 tasks
# Submitted 275 tasks
# Submitted 280 tasks
# Submitted 285 tasks
# Submitted 290 tasks
# Submitted 295 tasks
# Submitted 300 tasks
# Submitted 305 tasks
# Submitted 310 tasks
# Submitted 315 tasks
# Submitted 320 tasks
# Submitted 325 tasks
# Submitted 330 tasks
# Submitted 335 tasks
# Submitted 340 tasks
# Submitted 345 tasks
# Submitted 350 tasks
# Submitted 355 tasks
# Submitted 360 tasks
# Submitted 365 tasks
# Submitted 370 tasks
# Submitted 375 tasks
# Submitted 380 tasks
# Submitted 385 tasks
# Submitted 390 tasks
# Submitted 395 tasks
# Submitted 400 tasks
# Submitted 405 tasks
# Submitted 410 tasks
# Submitted 415 tasks
# Submitted 420 tasks
# Submitted 425 tasks
# Submitted 430 tasks
# Submitted 435 tasks
# Submitted 440 tasks
# Submitted 445 tasks
# Submitted 450 tasks
# Submitted 455 tasks
# Submitted 460 tasks
# Submitted 465 tasks
# Submitted 470 tasks
# Submitted 475 tasks
# Submitted 480 tasks
# Submitted 485 tasks
# Submitted 490 tasks
# Submitted 495 tasks
# Submitted 500 tasks
# Submitted 505 tasks
# Submitted 510 tasks
# Submitted 515 tasks
# Submitted 520 tasks
# Submitted 525 tasks
# Submitted 530 tasks
# Submitted 535 tasks
# Submitted 540 tasks
# Submitted 545 tasks
# Submitted 550 tasks
# Submitted 555 tasks
# Submitted 560 tasks
# Submitted 565 tasks
# Submitted 570 tasks
# Submitted 575 tasks
# Submitted 580 tasks
# Submitted 585 tasks
# Submitted 590 tasks
# Submitted 595 tasks
# Submitted 600 tasks
# Submitted 605 tasks
# Submitted 610 tasks
# Submitted 615 tasks
# Submitted 620 tasks
# Submitted 625 tasks
# Submitted 630 tasks
# Submitted 635 tasks
# Submitted 640 tasks
# Submitted 645 tasks
# Submitted 650 tasks
# Submitted 655 tasks
# Submitted 660 tasks
# Submitted 665 tasks
# Submitted 670 tasks
# Submitted 675 tasks
# Submitted 680 tasks
# Submitted 685 tasks
# Submitted 690 tasks
# Submitted 695 tasks
# Submitted 700 tasks
# Submitted 705 tasks
# Submitted 710 tasks
# Submitted 715 tasks
# Submitted 720 tasks
# Submitted 725 tasks
# Submitted 730 tasks
# Submitted 735 tasks
# Submitted 740 tasks
# Submitted 745 tasks
# Submitted 750 tasks
# Submitted 755 tasks
# Submitted 760 tasks
# Submitted 765 tasks
# Submitted 770 tasks
# Submitted 775 tasks
# Submitted 780 tasks
# Submitted 785 tasks
# Submitted 790 tasks
# Submitted 795 tasks
# Submitted 800 tasks
# Submitted 805 tasks
# Submitted 810 tasks
# Submitted 815 tasks
# Submitted 820 tasks
# Submitted 825 tasks
# Submitted 830 tasks
# Submitted 835 tasks
# Submitted 840 tasks
# Submitted 845 tasks
# Submitted 850 tasks
# Submitted 855 tasks
# Submitted 860 tasks
# Submitted 865 tasks
# Submitted 870 tasks
# Submitted 875 tasks
# Submitted 880 tasks
# Submitted 885 tasks
# Submitted 890 tasks
# Submitted 895 tasks
# Submitted 900 tasks
# Submitted 905 tasks
# Submitted 910 tasks
# Submitted 915 tasks
# Submitted 920 tasks
# Submitted 925 tasks
# Submitted 930 tasks
# Submitted 935 tasks
# Submitted 940 tasks
# Submitted 945 tasks
# Submitted 950 tasks
# Submitted 955 tasks
# Submitted 960 tasks
# Submitted 965 tasks
# Submitted 970 tasks
# Submitted 975 tasks
# Submitted 980 tasks
# Submitted 985 tasks
# Submitted 990 tasks
# Submitted 995 tasks
# Submitted 1000 tasks
# Submitted 1005 tasks
# Submitted 1010 tasks
# Submitted 1015 tasks
# Submitted 1020 tasks
# Submitted 1025 tasks
# Submitted 1030 tasks
# Submitted 1035 tasks
# Submitted 1040 tasks
# Submitted 1045 tasks
# Submitted 1050 tasks
# Submitted 1055 tasks
# Submitted 1060 tasks
# Submitted 1065 tasks
# Submitted 1070 tasks
# Submitted 1075 tasks
# Submitted 1080 tasks
# Submitted 1085 tasks
# Submitted 1090 tasks
# Submitted 1095 tasks
# Submitted 1100 tasks
# Submitted 1105 tasks
# Submitted 1110 tasks
# Submitted 1115 tasks
# Submitted 1120 tasks
# Submitted 1125 tasks
# Submitted 1130 tasks
# Submitted 1135 tasks
# Submitted 1140 tasks
# Submitted 1145 tasks
# Submitted 1150 tasks
# Submitted 1155 tasks
# Submitted 1160 tasks
# Submitted 1165 tasks
# Submitted 1170 tasks
# Submitted 1175 tasks
# Submitted 1180 tasks
# Submitted 1185 tasks
# Submitted 1190 tasks
# Submitted 1195 tasks
# Submitted 1200 tasks
# Submitted 1205 tasks
# Submitted 1210 tasks
# Submitted 1215 tasks
# Submitted 1220 tasks
# Submitted 1225 tasks
# Submitted 1230 tasks
# Submitted 1235 tasks
# Submitted 1240 tasks
# Submitted 1245 tasks
# Submitted 1250 tasks
# Submitted 1255 tasks
# Submitted 1260 tasks
# Submitted 1265 tasks
# Submitted 1270 tasks
# Submitted 1275 tasks
# Submitted 1280 tasks
# Submitted 1285 tasks
# Submitted 1290 tasks
# Submitted 1295 tasks
# Submitted 1300 tasks
# Submitted 1305 tasks
# Submitted 1310 tasks
# Submitted 1315 tasks
# Submitted 1320 tasks
# Submitted 1325 tasks
# Submitted 1330 tasks
# Submitted 1335 tasks
# Submitted 1340 tasks
# Submitted 1345 tasks
# Submitted 1350 tasks
# Submitted 1355 tasks
# Submitted 1360 tasks
# Submitted 1365 tasks
# Submitted 1370 tasks
# Submitted 1375 tasks
# Submitted 1380 tasks
# Submitted 1385 tasks
# Submitted 1390 tasks
# Submitted 1395 tasks
# Submitted 1400 tasks
# Submitted 1405 tasks
# Submitted 1410 tasks
# Submitted 1415 tasks
# Submitted 1420 tasks
# Submitted 1425 tasks
# Submitted 1430 tasks
# Submitted 1435 tasks
# Submitted 1440 tasks
# Submitted 1445 tasks
# Submitted 1450 tasks
# Submitted 1455 tasks
# Submitted 1460 tasks
# Submitted 1465 tasks
# Submitted 1470 tasks
# Submitted 1475 tasks
# Submitted 1480 tasks
# Submitted 1485 tasks
# Submitted 1490 tasks
# Submitted 1495 tasks
# Submitted 1500 tasks
# [RetryError(<Future at 0x180212b07c0 state=finished raised APIConnectionError>), {'question': 'Region: India, Question: Mating in sheep is called? Answer options: A: Serving, B: Tupping, C: Coupling, D: Lambing, E: Calving', 'template_answer': 'B', 'llm_answer': Message(id='msg_01TnrVVX9E5bMTLUQDojYZsC', content=[ContentBlock(text='The correct answer is B: Tupping.\n\nThe mating process in sheep is called "tupping" or "tup" (ram mating with ewes).', type='text')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=65, output_tokens=39)), 'model': 'claude_3_sonnet', 'region': 'India', 'prompt': 'Answer the given question. Return the LETTER of the correct answer.'}, RetryError(<Future at 0x1800e932050 state=finished raised AttributeError>), RetryError(<Future at 0x1800e961de0 state=finished raised RateLimitError>), {'question': 'Region: India, Question: Mating in sheep is called? Answer options: A: Serving, B: Tupping, C: Coupling, D: Lambing, E: Calving', 'template_answer': 'B', 'llm_answer': Message(id='msg_01WHGvRwo9M82VnwcEZwThPm', content=[ContentBlock(text='The correct answer is B: Tupping.\n\nIn the context of sheep breeding, the term "tupping" refers to the mating or breeding process between a ram (male sheep) and ewes (female sheep). It is the specific term used to describe the act of a ram serving or mating with ewes during the breeding season.', type='text')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=74, output_tokens=74)), 'model': 'claude_3_sonnet', 'region': 'India', 'prompt': 'You are an expert in agriculture. Answer the given question about agriculture. Return the LETTER of the correct answer.'}, RetryError(<Future at 0x1800cd5ec80 state=finished raised APIConnectionError>), RetryError(<Future at 0x18014eaead0 state=finished raised APIConnectionError>), {'question': 'Region: India, Question: Mating in sheep is called? Answer options: A: Serving, B: Tupping, C: Coupling, D: Lambing, E: Calving', 'template_answer': 'B', 'llm_answer': Message(id='msg_01WUHmf8es2owycBYxzjGEZF', content=[ContentBlock(text='The correct answer is B: Tupping.\n\nThe mating process in sheep is called "tupping." This term specifically refers to the act of a male ram mating with or breeding with a female ewe during the breeding season.', type='text')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=87, output_tokens=52)), 'model': 'claude_3_sonnet', 'region': 'India', 'prompt': 'You are an expert in agriculture. Answer the given question about agriculture truthfully, concisely, and precisely for the described location. Return the LETTER of the correct answer.'}, RetryError(<Future at 0x1800f025b40 state=finished raised RateLimitError>), RetryError(<Future at 0x18021bf7dc0 state=finished raised APIConnectionError>), {'question': 'Region: India, Question: Mating in sheep is called? Answer options: A: Serving, B: Tupping, C: Coupling, D: Lambing, E: Calving', 'template_answer': 'B', 'llm_answer': Message(id='msg_01RdsWRrcLaupMeA4Y5jzM9y', content=[ContentBlock(text='B) Tupping', type='text')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=117, output_tokens=8)), 'model': 'claude_3_sonnet', 'region': 'India', 'prompt': 'You are an expert in agriculture. Answer the given question about agriculture truthfully, concisely, and precisely for the described location. If you answer correctly, you will receive $1,000. If you answer incorrectly, you will be fined $1,000. Return the LETTER of the correct answer.'}, RetryError(<Future at 0x18021821ae0 state=finished raised RateLimitError>), RetryError(<Future at 0x180194f6680 state=finished raised RateLimitError>), {'question': 'Region: India, Questi ...
# An error occurred: RetryError[<Future at 0x180212b07c0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1800e932050 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800e961de0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800cd5ec80 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x18014eaead0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1800f025b40 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18021bf7dc0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x18021821ae0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x180194f6680 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800f79dea0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807c9d8430 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x18021fe4610 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1801bdbae90 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x180214ec0d0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1800d449540 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1807cb9d2d0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x18021c00c70 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x180222ea080 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18021fdf6a0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807ed656f0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18012798df0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x180210eee30 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18021fb5f60 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1801d00dea0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18014ed17e0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1800eb3ad40 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800f0272b0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18017bfc2b0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1801527de10 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18013cab1f0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18017fa4d30 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807feedea0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800c3900d0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x
 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807e6b0640 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807e8f3100 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800fc07940 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x180127e3700 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x180150f4b80 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18022143e50 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18013a5b2b0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e9bf040 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800625f190 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e851420 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800cd09a20 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800d953520 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807e9bdc90 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800755c5e0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x18021416710 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800edafe50 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800d461d20 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800ed40910 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800e85ada0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807e8f1c60 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807dfe5f00 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800fc07bb0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800fc07a60 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800dad3430 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800f526f20 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800cda6ec0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e89cd00 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x18015038280 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18021e59060 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800f02d840 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800c03c190 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807c7a2050 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e6b06d0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807eaf59f0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807de5a1a0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800cfa53f0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x180222bd8a0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807cacc580 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807eaf69e0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800cfa79a0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807ca977f0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1807cb3c9d0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e65d6f0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800cda6d70 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800bf956c0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x180038bf430 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807e624ee0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800c112620 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800cfa7b80 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800f02c5b0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807ea50ac0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800e24db40 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x180138999f0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800d462bf0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807cc102b0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800f2e54b0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807ea2a9e0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807e89f0a0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800f18cc10 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807c981b10 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x18013a5ad70 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800ecd36d0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18006288d30 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1800d465cf0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800d3ea380 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800bf94fa0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e9bf3d0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x18017d133a0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1807e91f610 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x18013899300 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800e85a170 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e65c460 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x180038d0520 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807eaf42e0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800e7804f0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x180038bdd20 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807ea53fd0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807cbb4fd0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x180075bfdf0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800ee654e0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800fb8f190 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e65dfc0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800d39cf40 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1807e117ac0 state=finished raised APIConnectionError>]
# An error occurred: RetryError[<Future at 0x1807e97c3a0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800d905b40 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800ed434f0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800d39f6a0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800ed43640 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e6b0b80 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1807e73fca0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800d905630 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x1800d39fac0 state=finished raised AttributeError>]
# An error occurred: RetryError[<Future at 0x180013cfbe0 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800628e410 state=finished raised RateLimitError>]
# An error occurred: RetryError[<Future at 0x1800c09e560 state=finished raised RateLimitError>]
#                                               question template_answer  \
# 0    Region: India, Question: Mating in sheep is ca...               B
# 1    Region: India, Question: Mating in sheep is ca...               B
# 2    Region: India, Question: Mating in sheep is ca...               B
# 3    Region: India, Question: Mating in sheep is ca...               B
# 4    Region: India, Question: Mating in sheep is ca...               B
# ..                                                 ...             ...
# 483  Region: India, Question: Akiochi disease in ri...               D
# 484  Region: India, Question: Akiochi disease in ri...               D
# 485  Region: India, Question: Akiochi disease in ri...               D
# 486  Region: India, Question: Akiochi disease in ri...               D
# 487  Region: India, Question: Akiochi disease in ri...               D
#
#                                             llm_answer            model  \
# 0    Message(id='msg_01TnrVVX9E5bMTLUQDojYZsC', con...  claude_3_sonnet
# 1    Message(id='msg_01WHGvRwo9M82VnwcEZwThPm', con...  claude_3_sonnet
# 2    Message(id='msg_01WUHmf8es2owycBYxzjGEZF', con...  claude_3_sonnet
# 3    Message(id='msg_01RdsWRrcLaupMeA4Y5jzM9y', con...  claude_3_sonnet
# 4    Message(id='msg_01RSXCKqcHNkwNczo9Ys3Kui', con...  claude_3_sonnet
# ..                                                 ...              ...
# 483  Message(id='msg_01F5a3wh6PUk4ofcRahAjz7J', con...  claude_3_sonnet
# 484  Message(id='msg_01733ji9Rk4hebx655hY5pN8', con...  claude_3_sonnet
# 485  Message(id='msg_01HcgnK1rKxFVq58ePovewKy', con...  claude_3_sonnet
# 486  Message(id='msg_01RpqLJRM4ZZUWoJrSos4cwf', con...  claude_3_sonnet
# 487  Message(id='msg_013BJeEbLnFXeybKod9SCEuy', con...  claude_3_sonnet
#
#     region                                             prompt
# 0    India  Answer the given question. Return the LETTER o...
# 1    India  You are an expert in agriculture. Answer the g...
# 2    India  You are an expert in agriculture. Answer the g...
# 3    India  You are an expert in agriculture. Answer the g...
# 4    India  You are an expert in agriculture. Answer the g...
# ..     ...                                                ...
# 483  India  Answer the given question. Return the LETTER o...
# 484  India  You are an expert in agriculture. Answer the g...
# 485  India  You are an expert in agriculture. Answer the g...
# 486  India  You are an expert in agriculture. Answer the g...
# 487  India  You are an expert in agriculture. Answer the g...
#
# [488 rows x 6 columns]

# %%
anthropic1 = pd.read_csv(r'../temp_data/quiz_results_anthropic_df1.csv', sep = ';')
anthropic2 = pd.read_csv(r'../temp_data/quiz_results_anthropic_df2.csv', sep = ';')

anthropic_df = pd.concat([anthropic1, anthropic2])
anthropic_df
# Out:
#                                               question template_answer  \
# 0    Region: India, Question: Glycolysis is known a...               A
# 1    Region: India, Question: Glycolysis is known a...               A
# 2    Region: India, Question: Glycolysis is known a...               A
# 3    Region: India, Question: Glycolysis is known a...               A
# 4    Region: India, Question: Glycolysis is known a...               A
# ..                                                 ...             ...
# 483  Region: India, Question: Akiochi disease in ri...               D
# 484  Region: India, Question: Akiochi disease in ri...               D
# 485  Region: India, Question: Akiochi disease in ri...               D
# 486  Region: India, Question: Akiochi disease in ri...               D
# 487  Region: India, Question: Akiochi disease in ri...               D
#
#                                             llm_answer            model  \
# 0    Message(id='msg_011SamNmjRi4KWsWSUEdMHge', con...  claude_3_sonnet
# 1    Message(id='msg_0188g8qKDrCFNsDXmwmC27qJ', con...  claude_3_sonnet
# 2    Message(id='msg_01KiMz1r6zqUQtGNMcwM8t87', con...  claude_3_sonnet
# 3    Message(id='msg_012kLMzkThkmvuesJjFmETCw', con...  claude_3_sonnet
# 4    Message(id='msg_01XNhGAXmBkGEFn8CStLhw6Y', con...  claude_3_sonnet
# ..                                                 ...              ...
# 483  Message(id='msg_01F5a3wh6PUk4ofcRahAjz7J', con...  claude_3_sonnet
# 484  Message(id='msg_01733ji9Rk4hebx655hY5pN8', con...  claude_3_sonnet
# 485  Message(id='msg_01HcgnK1rKxFVq58ePovewKy', con...  claude_3_sonnet
# 486  Message(id='msg_01RpqLJRM4ZZUWoJrSos4cwf', con...  claude_3_sonnet
# 487  Message(id='msg_013BJeEbLnFXeybKod9SCEuy', con...  claude_3_sonnet
#
#     region                                             prompt
# 0    India  Answer the given question. Return the LETTER o...
# 1    India  You are an expert in agriculture. Answer the g...
# 2    India  You are an expert in agriculture. Answer the g...
# 3    India  You are an expert in agriculture. Answer the g...
# 4    India  You are an expert in agriculture. Answer the g...
# ..     ...                                                ...
# 483  India  Answer the given question. Return the LETTER o...
# 484  India  You are an expert in agriculture. Answer the g...
# 485  India  You are an expert in agriculture. Answer the g...
# 486  India  You are an expert in agriculture. Answer the g...
# 487  India  You are an expert in agriculture. Answer the g...
#
# [1059 rows x 6 columns]

# %%
quiz_results_hf_df = pd.read_csv(r'../temp_data/quiz_eval_df.csv', sep = ';')
quiz_results_anthropic_df = pd.read_csv(r'../temp_data/quiz_eval_anthropicdf.csv', sep = ';')

quiz_results_total_df = pd.concat([quiz_results_hf_df, quiz_results_anthropic_df], ignore_index=True)
quiz_results_total_df
# Out:
#                                                 question template_answer  \
# 0      Region: India, Question: Glycolysis is known a...               A
# 1      Region: India, Question: Glycolysis is known a...               A
# 2      Region: India, Question: Glycolysis is known a...               A
# 3      Region: India, Question: Glycolysis is known a...               A
# 4      Region: India, Question: Glycolysis is known a...               A
# ...                                                  ...             ...
# 22094  Region: India, Question: Akiochi disease in ri...               D
# 22095  Region: India, Question: Akiochi disease in ri...               D
# 22096  Region: India, Question: Akiochi disease in ri...               D
# 22097  Region: India, Question: Akiochi disease in ri...               D
# 22098  Region: India, Question: Akiochi disease in ri...               D
#
#                                               llm_answer region  \
# 0      \n    Sure, here is the answer to the question...  India
# 1      \n    The correct answer is A. EMP pathway.\n\...  India
# 2      \n     A. A. Glycolysis is not an acronym, but...  India
# 3      \n    \n    A. EMP pathway\n\n    Explanation:...  India
# 4                 The correct answer is (A) EMP pathway.  India
# ...                                                  ...    ...
# 22094  Message(id='msg_01F5a3wh6PUk4ofcRahAjz7J', con...  India
# 22095  Message(id='msg_01733ji9Rk4hebx655hY5pN8', con...  India
# 22096  Message(id='msg_01HcgnK1rKxFVq58ePovewKy', con...  India
# 22097  Message(id='msg_01RpqLJRM4ZZUWoJrSos4cwf', con...  India
# 22098  Message(id='msg_013BJeEbLnFXeybKod9SCEuy', con...  India
#
#                  model                                             prompt  \
# 0          gemma_7b_it  Answer the given question. Return the LETTER o...
# 1          gemma_2b_it  Answer the given question. Return the LETTER o...
# 2           mistral_7b  Answer the given question. Return the LETTER o...
# 3         mistral_8x7b  Answer the given question. Return the LETTER o...
# 4            llama2_7b  Answer the given question. Return the LETTER o...
# ...                ...                                                ...
# 22094  claude_3_sonnet  Answer the given question. Return the LETTER o...
# 22095  claude_3_sonnet  You are an expert in agriculture. Answer the g...
# 22096  claude_3_sonnet  You are an expert in agriculture. Answer the g...
# 22097  claude_3_sonnet  You are an expert in agriculture. Answer the g...
# 22098  claude_3_sonnet  You are an expert in agriculture. Answer the g...
#
#       evaluation
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 22094          0
# 22095          1
# 22096          1
# 22097          1
# 22098          1
#
# [22099 rows x 7 columns]

# %% [markdown]
# # 4. Evaluation

# %%
evaluation_template = (
    """You are an expert in agriculture. Evaluate this answer given by a student for the provided question in comparison to the template answer. Provide as result the number 0 if the answer is incorrect, 1 if it is correct.
    Base your decision only on the template answer and the student's answer. Do not use any other information or knowledge.
    
    ALWAYS ONLY RETURN THE NUMBER!"""
)

# %%
oa_results = pd.read_csv(r'../temp_data/quiz_results_oa_df.csv', sep = ';')
hf_results = pd.read_csv(r'../temp_data/quiz_results_df.csv', sep = ';')

total_results = pd.concat([oa_results, hf_results], ignore_index=True)

random_questions = pd.DataFrame(brazil_results["question"].unique()).sample(n=50, replace=False)
random_questions

brazil_results = total_results[total_results['region'] == 'Brazil']
brazil_results = brazil_results[brazil_results['question'].isin(random_questions[0])]

brazil_results.to_csv(r'../temp_data/brazil_results.csv', sep = ';', index = False)
brazil_results
# Out:
#                                                 question  \
# 2940   Region: Brazil, Question: O algodoeiro herbáce...
# 2941   Region: Brazil, Question: O algodoeiro herbáce...
# 2942   Region: Brazil, Question: O algodoeiro herbáce...
# 2943   Region: Brazil, Question: O algodoeiro herbáce...
# 2944   Region: Brazil, Question: O algodoeiro herbáce...
# ...                                                  ...
# 20485  Region: Brazil, Question: O que é a análise se...
# 20486  Region: Brazil, Question: O que é a análise se...
# 20487  Region: Brazil, Question: O que é a análise se...
# 20488  Region: Brazil, Question: O que é a análise se...
# 20489  Region: Brazil, Question: O que é a análise se...
#
#                                          template_answer  \
# 2940   <p>O algodoeiro herbáceo é explorado no Brasil...
# 2941   <p>O algodoeiro herbáceo é explorado no Brasil...
# 2942   <p>O algodoeiro herbáceo é explorado no Brasil...
# 2943   <p>O algodoeiro herbáceo é explorado no Brasil...
# 2944   <p>O algodoeiro herbáceo é explorado no Brasil...
# ...                                                  ...
# 20485  <p>É a avaliação qualitativa do vinho, efetuad...
# 20486  <p>É a avaliação qualitativa do vinho, efetuad...
# 20487  <p>É a avaliação qualitativa do vinho, efetuad...
# 20488  <p>É a avaliação qualitativa do vinho, efetuad...
# 20489  <p>É a avaliação qualitativa do vinho, efetuad...
#
#                                               llm_answer          model  \
# 2940   A) Sim, mas somente no sistema de consórcio.\n...    gpt_4_turbo
# 2941                                              A) Sim  gpt_3_5_turbo
# 2942                                              A) Sim    gpt_4_turbo
# 2943   Letter A: Sim, o algodoeiro herbáceo pode ser ...  gpt_3_5_turbo
# 2944                                                Sim.    gpt_4_turbo
# ...                                                  ...            ...
# 20485  \n    **Thought:**\n\n* The analysis of sensor...    gemma_2b_it
# 20486  \n     Thought: The term "análise sensorial do...     mistral_7b
# 20487  \n    \n    Thought: A sensory analysis of win...   mistral_8x7b
# 20488    Thought: When it comes to the analysis of wi...      llama2_7b
# 20489    Sure, I'd be happy to help!\n\nThought:\n\nW...     llama2_13b
#
#        region                                             prompt
# 2940   Brazil  Answer the given question. Return the LETTER o...
# 2941   Brazil  Answer the given question. Return the LETTER o...
# 2942   Brazil  You are an expert in agriculture. Answer the g...
# 2943   Brazil  You are an expert in agriculture. Answer the g...
# 2944   Brazil  You are an expert in agriculture. Answer the g...
# ...       ...                                                ...
# 20485  Brazil  You are an expert in agriculture. Answer the g...
# 20486  Brazil  You are an expert in agriculture. Answer the g...
# 20487  Brazil  You are an expert in agriculture. Answer the g...
# 20488  Brazil  You are an expert in agriculture. Answer the g...
# 20489  Brazil  You are an expert in agriculture. Answer the g...
#
# [2000 rows x 6 columns]

# %%
oa_client = AsyncOpenAI()
limiter = AsyncLimiter(30, 1)

class TaskStatus:
    def __init__(self, task_id):
        self.task_id = task_id
        self.status = "pending"
        self.attempt = 0

    def update_status(self, status):
        self.status = status

    def increment_attempt(self):
        self.attempt += 1

def update_task_status(retry_state: RetryCallState):
    task_status = retry_state.args[0]  # Assuming the first argument is the TaskStatus object
    task_status.update_status("retrying")
    task_status.increment_attempt()

@retry(wait=wait_random_exponential(min=1, max=20),
       stop=stop_after_attempt(100),
       retry_error_callback=update_task_status)
async def async_gpt_3_5_turbo(task_status, prompt, user_input):
    response = await oa_client.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=[
            {"role": "system", "content": prompt},
            {"role": "user", "content": user_input}
        ]
    )
    task_status.update_status("completed")
    return response.choices[0].message.content

@retry(wait=wait_random_exponential(min=1, max=20),
       stop=stop_after_attempt(100),
       retry_error_callback=update_task_status)
async def async_gpt_4_turbo(task_status, prompt, user_input):
    response = await oa_client.chat.completions.create(
        model="gpt-4-turbo-preview",
        messages=[
            {"role": "system", "content": prompt},
            {"role": "user", "content": user_input}
        ]
    )
    task_status.update_status("completed")
    return response.choices[0].message.content


async def async_eval(task_status, prompt, row):
    input_str = "student answer: " + row["llm_answer"] + "; correct answer: " + row["template_answer"]
    result = await async_gpt_4_turbo(task_status, evaluation_template, input_str)
    new_row = row.copy()
    new_row['evaluation'] = result
    return new_row

async def process_documents(documents_df):
    tasks = []
    task_statuses = []
    for index, row in documents_df.iterrows():
        async with limiter:
            task_status = TaskStatus(task_id=index)
            task_statuses.append(task_status)
            task = asyncio.create_task(async_eval(task_status, evaluation_template, row))
            tasks.append(task)
            if len(tasks) % 10 == 0:
                print(f"Submitted {len(tasks)} tasks")

    while True:
        completed_count = sum(1 for task_status in task_statuses if task_status.status == "completed")
        total_count = len(tasks)
        progress_percentage = (completed_count / total_count) * 100
        print(f"Progress: {progress_percentage:.5f}%")

        if all(task_status.status == "completed" for task_status in task_statuses):
            break

        await asyncio.sleep(1)

    results = await asyncio.gather(*tasks, return_exceptions=True)
    return pd.DataFrame([result for result in results if not isinstance(result, Exception)])






subset_df = pd.read_csv(r'../temp_data/brazil_results.csv', sep = ';')
print(len(subset_df))

synth_qa_eval_df = pd.DataFrame()

for i in range(0, len(subset_df), 25):
    print("#################################  ", i)
    loop = asyncio.get_event_loop()
    # In case the loop is already running, avoid using loop.run_until_complete()
    if not loop.is_running():
        synth_qa_eval_df_new = loop.run_until_complete(process_documents(subset_df[i:i+25]))
    else:
        synth_qa_eval_df_new = await process_documents(subset_df[i:i+25])

    synth_qa_eval_df = pd.concat([synth_qa_eval_df, synth_qa_eval_df_new], ignore_index=True)

    synth_qa_eval_df.to_csv(r'../temp_data/quiz_eval_brazil_gpt_4.csv', sep=';', index=False)

synth_qa_eval_df
# Out:
# 2000
# #################################   0
# Submitted 10 tasks
# Submitted 20 tasks
# Progress: 0.00000%
# Progress: 60.00000%
# Progress: 100.00000%
# #################################   25
# Submitted 10 tasks
# Submitted 20 tasks
# Progress: 0.00000%
# Progress: 40.00000%
# Progress: 92.00000%
# Progress: 96.00000%
# Progress: 96.00000%
# Progress: 100.00000%
# #################################
00000%
# Progress: 92.00000%
# Progress: 92.00000%
# Progress: 92.00000%
# Progress: 92.00000%
# Progress: 92.00000%
# Progress: 92.00000%
# Progress: 96.00000%
# Progress: 96.00000%
# Progress: 96.00000%
# Progress: 96.00000%
# Progress: 96.00000%
# Progress: 100.00000%
# #################################   1975
# Submitted 10 tasks
# Submitted 20 tasks
# Progress: 0.00000%
# Progress: 44.00000%
# Progress: 100.00000%
#                                                question  \
# 0     Region: Brazil, Question: O algodoeiro herbáce...
# 1     Region: Brazil, Question: O algodoeiro herbáce...
# 2     Region: Brazil, Question: O algodoeiro herbáce...
# 3     Region: Brazil, Question: O algodoeiro herbáce...
# 4     Region: Brazil, Question: O algodoeiro herbáce...
# ...                                                 ...
# 1995  Region: Brazil, Question: O que é a análise se...
# 1996  Region: Brazil, Question: O que é a análise se...
# 1997  Region: Brazil, Question: O que é a análise se...
# 1998  Region: Brazil, Question: O que é a análise se...
# 1999  Region: Brazil, Question: O que é a análise se...
#
#                                         template_answer  \
# 0     <p>O algodoeiro herbáceo é explorado no Brasil...
# 1     <p>O algodoeiro herbáceo é explorado no Brasil...
# 2     <p>O algodoeiro herbáceo é explorado no Brasil...
# 3     <p>O algodoeiro herbáceo é explorado no Brasil...
# 4     <p>O algodoeiro herbáceo é explorado no Brasil...
# ...                                                 ...
# 1995  <p>É a avaliação qualitativa do vinho, efetuad...
# 1996  <p>É a avaliação qualitativa do vinho, efetuad...
# 1997  <p>É a avaliação qualitativa do vinho, efetuad...
# 1998  <p>É a avaliação qualitativa do vinho, efetuad...
# 1999  <p>É a avaliação qualitativa do vinho, efetuad...
#
#                                              llm_answer          model  \
# 0     A) Sim, mas somente no sistema de consórcio.\n...    gpt_4_turbo
# 1                                                A) Sim  gpt_3_5_turbo
# 2                                                A) Sim    gpt_4_turbo
# 3     Letter A: Sim, o algodoeiro herbáceo pode ser ...  gpt_3_5_turbo
# 4                                                  Sim.    gpt_4_turbo
# ...                                                 ...            ...
# 1995  \n    **Thought:**\n\n* The analysis of sensor...    gemma_2b_it
# 1996  \n     Thought: The term "análise sensorial do...     mistral_7b
# 1997  \n    \n    Thought: A sensory analysis of win...   mistral_8x7b
# 1998    Thought: When it comes to the analysis of wi...      llama2_7b
# 1999    Sure, I'd be happy to help!\n\nThought:\n\nW...     llama2_13b
#
#       region                                             prompt evaluation
# 0     Brazil  Answer the given question. Return the LETTER o...          1
# 1     Brazil  Answer the given question. Return the LETTER o...          1
# 2     Brazil  You are an expert in agriculture. Answer the g...          1
# 3     Brazil  You are an expert in agriculture. Answer the g...          1
# 4     Brazil  You are an expert in agriculture. Answer the g...          1
# ...      ...                                                ...        ...
# 1995  Brazil  You are an expert in agriculture. Answer the g...          1
# 1996  Brazil  You are an expert in agriculture. Answer the g...          1
# 1997  Brazil  You are an expert in agriculture. Answer the g...          1
# 1998  Brazil  You are an expert in agriculture. Answer the g...          1
# 1999  Brazil  You are an expert in agriculture. Answer the g...          1
#
# [2000 rows x 7 columns]
